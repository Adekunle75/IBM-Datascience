# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter notebook on Watson Studio

# %% [markdown]
# **Adekunle Afolabi**
# Data Scientist

# %% [markdown]
# *The use of data for drawing inferences as always intrigued me, since i first did statistics in my undergraduate*

# %% [markdown]
# ### The code below creates the first 50 fibonacci sequence

# %%
def fib(x):
    sequence = [1,1]
    for i in range(2,x):
        sequence.append(sequence[-2] + sequence[-1])
    print(sequence)
fib(50)

# %% [markdown]
# #### Merits of Collaboration
# * Better decision making
# * Increased Efficiency
# * Better resource utilisation
# * ~~Money Loss~~
# ****
